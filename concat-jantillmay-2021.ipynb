# %%
import pandas as pd
import numpy as np

# %%
##Import dataset from 2021 Jan to May and creating dataframes
rawjan = pd.read_csv("Data/jan 2021.csv")
df1 = pd.DataFrame(rawjan)
df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           146  2020-12-01 00:02:50.1450  2020-12-01 00:05:16.1940
# 1           572  2020-12-01 00:11:57.3910  2020-12-01 00:21:30.2510
# 2           387  2020-12-01 00:14:49.3610  2020-12-01 00:21:16.8730
# 3           188  2020-12-01 00:45:06.3680  2020-12-01 00:48:14.4280
# 4           594  2020-12-01 01:17:17.0110  2020-12-01 01:27:11.9400
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3640     Journal Square               40.733670
# 2              3640     Journal Square               40.733670
# 3              3186      Grove St PATH               40.719586
# 4              3212    Christ Hospital               40.734786
#
#    start station longitude  end station id end station name  \
# 0               -74.033759            3199     Newport Pkwy
# ...

# %%
rawfeb = pd.read_csv("Data/feb 2021.csv")
df2 = pd.DataFrame(rawfeb)
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1          1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2          1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3           793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4           596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
#
#    start station id start station name  start station latitude  \
# 0              3273       Manila & 1st               40.721651
# 1              3681           Grand St               40.715178
# 2              3681           Grand St               40.715178
# 3              3185          City Hall               40.717732
# 4              3639         Harborside               40.719252
#
#    start station longitude  end station id end station name  \
# 0               -74.042884            3209     Brunswick St
# ...

# %%
rawapril = pd.read_csv("Data/april 2021.csv")
df3 = pd.DataFrame(rawapril)
df3.head()
# Out:
#    tripduration starttime stoptime  start station id  \
# 0          1753   00:00.1  29:13.1              3113
# 1           131   00:01.0  02:12.8              2012
# 2          1318   00:02.6  22:01.2              3746
# 3           199   00:03.9  03:23.6               540
# 4          1594   00:06.1  26:40.4              3123
#
#                start station name  start station latitude  \
# 0  Greenpoint Ave & Manhattan Ave               40.730260
# 1                 E 27 St & 1 Ave               40.739445
# 2               6 Ave & Broome St               40.724308
# 3         Lexington Ave & E 29 St               40.743116
# 4             31 St & Thomson Ave               40.744697
#
#    start station longitude  end station id             end station name  \
# 0               -73.953940            3165  Central Park West & W 72 St
# 1               -73.976806             174              E 25 St & 1 Ave
# 2               -74.004730            3414     Bergen St & Flatbush Ave
# ...

# %%
rawmay = pd.read_csv("Data/may 2021.csv")
df4 = pd.DataFrame(rawmay)
df4.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           370  2021-04-01 00:00:02.8730  2021-04-01 00:06:13.3450
# 1          2102  2021-04-01 00:00:04.7670  2021-04-01 00:35:07.2640
# 2           306  2021-04-01 00:00:05.9260  2021-04-01 00:05:12.0290
# 3           425  2021-04-01 00:00:07.5420  2021-04-01 00:07:13.4670
# 4           107  2021-04-01 00:00:16.4570  2021-04-01 00:02:04.4020
#
#    start station id             start station name  start station latitude  \
# 0              4111           E 27 St & Park Ave S               40.742752
# 1              3087  Metropolitan Ave & Meeker Ave               40.714133
# 2               465             Broadway & W 41 St               40.755136
# 3              3093           N 6 St & Bedford Ave               40.717452
# 4              3724     7 Ave & Central Park South               40.766741
#
#    start station longitude  end station id        end station name  \
# ...

# %% [raw]
# # Concatenate all the dataframes, remove any row that has NaN values,

# %%
df_all =  pd.concat([df1, df2, df3, df4], ignore_index=True)
df_all.tail()
# Out:
#          tripduration                 starttime                  stoptime  \
# 3088039           711  2021-04-30 23:59:55.2130  2021-05-01 00:11:46.4140
# 3088040           687  2021-04-30 23:59:55.6720  2021-05-01 00:11:22.8090
# 3088041          1511  2021-04-30 23:59:56.2250  2021-05-01 00:25:07.7140
# 3088042           781  2021-04-30 23:59:56.3250  2021-05-01 00:12:58.1230
# 3088043          1295  2021-04-30 23:59:57.0600  2021-05-01 00:21:32.6890
#
#          start station id              start station name  \
# 3088039              3131                 E 68 St & 3 Ave
# 3088040              3839  Putnam Ave & Knickerbocker Ave
# 3088041               232     Cadman Plaza E & Tillary St
# 3088042              3705       Thompson St & Bleecker St
# 3088043              3507             Park Ave & E 124 St
#
#          start station latitude  start station longitude  end station id  \
# 3088039               40.767128               -73.962246            3175
# ...

# %%
df_all['gender']
# Out:
# 0          2
# 1          2
# 2          1
# 3          1
# 4          1
#           ..
# 3088039    0
# 3088040    0
# 3088041    0
# 3088042    0
# 3088043    0
# Name: gender, Length: 3088044, dtype: int64

# %% [raw]
# # Changing the gender from int to text

# %%
df_all['Gender'] = df_all['gender'].replace([0,1,2],['unknown',"Male","Female"])
df_all = df_all.drop('gender',1)
df_all["distance"] = ''
df_all.tail()
# Out:
#          tripduration                 starttime                  stoptime  \
# 3088039           711  2021-04-30 23:59:55.2130  2021-05-01 00:11:46.4140
# 3088040           687  2021-04-30 23:59:55.6720  2021-05-01 00:11:22.8090
# 3088041          1511  2021-04-30 23:59:56.2250  2021-05-01 00:25:07.7140
# 3088042           781  2021-04-30 23:59:56.3250  2021-05-01 00:12:58.1230
# 3088043          1295  2021-04-30 23:59:57.0600  2021-05-01 00:21:32.6890
#
#          start station id              start station name  \
# 3088039              3131                 E 68 St & 3 Ave
# 3088040              3839  Putnam Ave & Knickerbocker Ave
# 3088041               232     Cadman Plaza E & Tillary St
# 3088042              3705       Thompson St & Bleecker St
# 3088043              3507             Park Ave & E 124 St
#
#          start station latitude  start station longitude  end station id  \
# 3088039               40.767128               -73.962246            3175
# ...

# %%
df_all.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  3.088044e+06      3.088044e+06            3.088044e+06
# mean   1.154383e+03      2.259220e+03            4.074099e+01
# std    1.195520e+04      1.587346e+03            3.733314e-02
# min    6.100000e+01      7.200000e+01            4.063338e+01
# 25%    3.740000e+02      4.470000e+02            4.071689e+01
# 50%    6.680000e+02      3.148000e+03            4.074098e+01
# 75%    1.194000e+03      3.619000e+03            4.076501e+01
# max    2.899719e+06      4.502000e+03            4.087305e+01
#
#        start station longitude  end station id  end station latitude  \
# count             3.088044e+06    3.088044e+06          3.088044e+06
# mean             -7.397642e+01    2.254970e+03          4.074061e+01
# std               2.459083e-02    1.587858e+03          3.716792e-02
# min              -7.408364e+01    7.200000e+01          4.063338e+01
# ...

# %%
pd.seriespop = df_all(" ".join(df["text"]).split()).most_common()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-387c7ecedc80> in <module>
# ----> 1 pd.seriespop = df_all(" ".join(df["text"]).split()).most_common()
#
# NameError: name 'df' is not defined

# %%
df_all.isnull().any() # Null values in column "Birth Year" detected
# Out:
# tripduration               False
# starttime                  False
# stoptime                   False
# start station id           False
# start station name         False
# start station latitude     False
# start station longitude    False
# end station id             False
# end station name           False
# end station latitude       False
# end station longitude      False
# bikeid                     False
# usertype                   False
# birth year                 False
# Gender                     False
# distance                   False
# dtype: bool

# %% [raw]
# # # saving the data in csv format

# %%
df_all.to_csv('Data/final_tripdata.csv', index_label = "TripID")
